# %%
import pandas as pd
import geopandas as gpd

# %%
pd.read_parquet(r"C:\Users\eks510\OneDrive - Vrije Universiteit Amsterdam\2_Projects\MIRACA\MIRACA_results_exposure\PRT_rail_heat_exposure.parquet")'heat_40C_rcp_8_5_abs_change_recent_to_far_future_max'
# Out:
# metric      osm_id  abs_change_30C_rcp_4_5_recent_to_distant_future_mean  \
# 0        266066618                                          14.380000
# 1        690172071                                           7.981481
# 2        156513662                                          14.380000
# 3       1178482198                                           1.333333
# 4        153646253                                          10.707037
# ...            ...                                                ...
# 7980     153954959                                          22.008889
# 7981    1177965940                                          28.321852
# 7982     210678134                                           6.151111
# 7983    1180275844                                           4.541852
# 7984     155422228                                          19.894444
#
# metric  abs_change_30C_rcp_4_5_recent_to_far_future_mean  \
# 0                                              15.104444
# ...

# %%
gpd.read_parquet(r"C:\MIRACA\exposure\PRT_rail_exposure.parquet")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\OneDrive - Vrije Universiteit Amsterdam\12_repositories\AssetRisk_PanEU\.venv\Lib\site-packages\geopandas\io\arrow.py:654, in _read_parquet_schema_and_metadata(path, filesystem)
#     653 try:
# --> 654     schema = parquet.ParquetDataset(path, filesystem=filesystem, **kwargs).schema
#     655 except Exception:
#
# File ~\OneDrive - Vrije Universiteit Amsterdam\12_repositories\AssetRisk_PanEU\.venv\Lib\site-packages\pyarrow\parquet\core.py:1438, in ParquetDataset.__init__(self, path_or_paths, filesystem, schema, filters, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
# ...
