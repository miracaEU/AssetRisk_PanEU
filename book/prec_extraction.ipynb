# %%
import cdsapi
import xarray as xr
import multiprocessing as mp
from pathlib import Path
import os

dictionary = [
#    ["cordex_eur_11", "historical", "euro_cordex", "1970-2005"],
#    ["cordex_eur_11", "rcp_2_6", "euro_cordex", "2006-2100"],
#    ["cordex_eur_11", "rcp_4_5", "euro_cordex", "2006-2100"],
    ["cordex_eur_11", "rcp_8_5", "euro_cordex", "2006-2100"],
]
dictionary_obs = [["e_obs", "europe", "1950-2021"]]


def download_data_era5(variable, origin, domain, period):
    output_path = ()  ### fill with your path

    dataset = "multi-origin-c3s-atlas"
    request = {
        "origin": origin,
        "domain": domain,
        "period": period,
        "variable": variable,
        "bias_adjustment": "no_bias_adjustment",
    }

    client = cdsapi.Client()
    target = output_path + f"{variable}_{origin}_{domain}_{period}.nc"
    # print(f"Downloading {target}...")
    client.retrieve(dataset, request, target)
    print(f"{variable}_{origin}_{domain}_{period}.nc")


def download_data(variable, origin, experiment, domain, period):
    output_path = ('')  ### fill with your path
    dataset = "multi-origin-c3s-atlas"
    request = {
        "origin": origin,
        "experiment": experiment,
        "domain": domain,
        "period": period,
        "variable": variable,
        "bias_adjustment": "no_bias_adjustment",
    }

    
    apikey = '82a6b233-71db-4887-b976-0ce3f290e99c' # Enter your personal API key
    
    client = cdsapi.Client(key=f"{apikey}", url="https://cds.climate.copernicus.eu/api")

    target = output_path + f"{variable}_{origin}_{experiment}_{domain}_{period}.nc"
    # print(f"Downloading {target}...")
    client.retrieve(dataset, request, target)
    print(f"{variable}_{origin}_{experiment}_{domain}_{period}.nc")

# %%
variables = [
    "monthly_maximum_1_day_precipitation",
]

# %%
for vs in variables:
    new_dictionary  = [[vs] + entry for entry in dictionary]
    for inputs in new_dictionary:
        download_data(*inputs)
    #pool.starmap(download_data, new_dictionary)
    #new_dictionary_obs = [[vs] + entry for entry in dictionary_obs]
    #pool.starmap(download_data_era5, new_dictionary_obs)
    #print(f"Finished downloading {vs} data.")

# %%
historic = xr.open_dataset(r"C:\Users\eks510\OneDrive - Vrije Universiteit Amsterdam\12_repositories\AssetRisk_PanEU\src\monthly_maximum_1_day_precipitation_cordex_eur_11_historical_euro_cordex_1970-2005.nc", engine="netcdf4")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\pygis\Lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~\.conda\envs\pygis\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('C:\\Users\\eks510\\OneDrive - Vrije Universiteit Amsterdam\\12_repositories\\AssetRisk_PanEU\\src\\monthly_maximum_1_day_precipitation_cordex_eur_11_historical_euro_cordex_1970-2005.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '025e3b1d-69c1-48fa-836d-0e0868edfc16']
#
# ...
